# %%
import random
from tensorflow.keras.optimizers import SGD
from keras.layers import Dense, Dropout
from keras.models import load_model
from keras.models import Sequential
import numpy as np
import pickle
import json
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('omw-1.4')
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# WARNING:tensorflow:From e:\my_projects\convocraft_chatbot\env_chat\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ashch\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ashch\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ashch\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# init
words = []
classes = []
documents = []
ignore_words = ["?", "!"]
data_file = open("intent.json").read()
intents = json.loads(data_file)

# %%
# words
for intent in intents["intents"]:
    for pattern in intent["patterns"]:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent["tag"]))

        # adding classes to our class list
        if intent["tag"] not in classes:
            classes.append(intent["tag"])

# %%
# lemmatizer
words = [lemmatizer.lemmatize(w.lower())
         for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print(len(documents), "documents")

print(len(classes), "classes", classes)

print(len(words), "unique lemmatized words", words)


pickle.dump(words, open("words.pkl", "wb"))
pickle.dump(classes, open("classes.pkl", "wb"))
# Out:
# 103 documents
# 57 classes ['AI', 'abbr', 'artificial', 'bend', 'body', 'bot1', 'breathe', 'business', 'chatbot', 'chatterbox', 'clone', 'comp', 'computer', 'control', 'cramped', 'creator', 'date', 'death', 'do', 'events', 'fav', 'fight', 'goodbye', 'greetings', 'hardware', 'hobby', 'idea', 'immortal', 'lang', 'laugh', 'lie', 'machine', 'malfunction', 'motormouth', 'move', 'name', 'name1', 'need', 'noanswer', 'os', 'poem', 'program', 'programming', 'ratchet', 'robotics', 'robots', 'robotss', 'sapient', 'sense', 'sentiment', 'shoe', 'sound', 'stupid', 'thanks', 'usage', 'who', 'wt']
# 130 unique lemmatized words ["'m", "'s", ',', 'a', 'ai', 'all', 'allowed', 'am', 'an', 'are', 'artificial', 'awesome', 'be', 'being', 'bend', 'body', 'bot', 'breathe', 'business', 'bye', 'can', 'chat', 'chatterbox', 'clone', 'coffee', 'computer', 'control', 'cramped', 'creator', 'data', 'date', 'die', 'do', 'entity', 'event', 'favorite', 'favour', 'fight', 'for', 'good', 'great', 'hardware', 'haroo', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hobby', 'holla', 'hope', 'how', 'i', 'idea', 'immortal', 'in', 'is', 'it', 'jaw', 'kind', 'language', 'later', 'laugh', 'lie', 'like', 'linguistic', 'made', 'making', 'malfunction', 'mate', 'me', 'motormouth', 'move', 'my', 'name', 'need', 'not', 'of', 'okay', 'on', 'operating', 'out', 'over', 'poem', 'popping', 'product', 'program', 'programming', 'purpose', 'ratchet', 'robot', 'robotics', 'sapient', 'see', 'sense', 'sentient', 'shoe', 'should', 'size', 'sound', 'stupid', 'system', 'take', 'tell', 'thank', 'thanks', 'thankyou', 'that', 'the', 'there', 'to', 'true', 'type', 'upcoming', 'use', 'walk', 'want', 'wassup', 'what', 'when', 'who', 'will', 'work', 'wow', 'written', 'wtf', 'yaw', 'you', 'your']

# %%
# training initializer
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(
        word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# shuffle our features and turn into np.array
random.shuffle(training)

# %%
# Separate bag-of-words representations and output labels
train_x = [item[0] for item in training]
train_y = [item[1] for item in training]

# %%
# Convert to NumPy arrays
train_x = np.array(train_x)
train_y = np.array(train_y)
print("Training data created")
# Out:
# Training data created

# %%
# actual training
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))
model.summary()
# Out:
# WARNING:tensorflow:From e:\my_projects\convocraft_chatbot\env_chat\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               16768
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 57)                3705
#
# =================================================================
# Total params: 28729 (112.22 KB)
# Trainable params: 28729 (112.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd, metrics=["accuracy"])

# %%
hist = model.fit(np.array(train_x), np.array(train_y),
                 epochs=200, batch_size=5, verbose=1)
model.save("chatbot_model.h5", hist)
print("model created")
# Out:
# Epoch 1/200
# WARNING:tensorflow:From e:\my_projects\convocraft_chatbot\env_chat\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From e:\my_projects\convocraft_chatbot\env_chat\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 21/21 [==============================] - 1s 2ms/step - loss: 4.0552 - accuracy: 0.0485
# Epoch 2/200
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0095 - accuracy: 0.0680
# Epoch 3/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.8766 - accuracy: 0.1068
# Epoch 4/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.8515 - accuracy: 0.1165
# Epoch 5/200
# 21/21 [==============================] - 0s 2ms/step - loss: 3.7339 - accuracy: 0.1359
# Epoch 6/200
# 21/21 [==============================] - 0s 1ms/step - loss: 3.7269 - accuracy: 0.1359
# Epoch 7/200
# 21/21 [==============================] - 0s 1ms/step - loss: 3.5888 - accuracy: 0.1553
# Epoch 8/200
# 21/21 [==============================] - 0s 1ms/step - loss: 3.4951 - accuracy: 0.1650
# Epoch 9/200
# 21/21 [==============================] - 0s 1ms/step - loss: 3.4750 - accuracy: 0.1748
# Epoch 10/200
# 21/21 [==============================] - 0s 1ms/step - loss: 3.3141 - accuracy: 0.1845
# Epoch 11/200
# 21/21 [==============================] - 0s 1ms/step - loss: 3.1655 - accuracy: 0.2718
# Epoch 12/200
# 21/21 [==============================] - 0s 1ms/step - loss: 3.0643 - accuracy: 0.2330
# Epoch 13/200
# 21/21 [==============================] - 0s 1ms/step - loss: 3.0167 - accuracy: 0.2524
# Epoch 14/200
# 21/21 [==============================] - 0s 1ms/step - loss: 2.7769 - accuracy: 0.2718
# Epoch 15/200
# 21/21 [==============================] - 0s 1ms/step - loss: 2.8407 - accuracy: 0.3107
# Epoch 16/200
# 21/21 [==============================] - 0s 1ms/step - loss: 2.6645 - accuracy: 0.3107
# Epoch 17/200
# 21/21 [==============================] - 0s 1ms/step - loss: 2.6624 - accuracy: 0.3592
# Epoch 18/200
# 21/21 [==============================] - 0s 1ms/step - loss: 2.5572 - accuracy: 0.3301
# Epoch 19/200
# 21/21 [==============================] - 0s 2ms/step - loss: 2.3148 - accuracy: 0.3495
# Epoch 20/200
# 21/21 [==============================] - 0s 1ms/step - loss: 2.3287 - accuracy: 0.4466
# Epoch 21/200
# 21/21 [==============================] - 0s 1ms/step - loss: 2.1819 - accuracy: 0.4563
# Epoch 22/200
# 21/21 [==============================] - 0s 1ms/step - loss: 2.1547 - accuracy: 0.4466
# Epoch 23/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.9747 - accuracy: 0.5631
# Epoch 24/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.9863 - accuracy: 0.4757
# Epoch 25/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.8592 - accuracy: 0.4951
# Epoch 26/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.9097 - accuracy: 0.4951
# Epoch 27/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.8122 - accuracy: 0.5340
# Epoch 28/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.7129 - accuracy: 0.5243
# Epoch 29/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.6567 - accuracy: 0.5922
# Epoch 30/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.6058 - accuracy: 0.5631
# Epoch 31/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.6800 - accuracy: 0.4951
# Epoch 32/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.4138 - accuracy: 0.5922
# Epoch 33/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.3543 - accuracy: 0.6408
# Epoch 34/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.3870 - accuracy: 0.6311
# Epoch 35/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.4832 - accuracy: 0.5534
# Epoch 36/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.5357 - accuracy: 0.5631
# Epoch 37/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.3217 - accuracy: 0.6602
# Epoch 38/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.2803 - accuracy: 0.6602
# Epoch 39/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.2110 - accuracy: 0.6408
# Epoch 40/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.1831 - accuracy: 0.6602
# Epoch 41/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.3056 - accuracy: 0.6311
# Epoch 42/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.1996 - accuracy: 0.6602
# Epoch 43/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.0151 - accuracy: 0.7087
# Epoch 44/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.1001 - accuracy: 0.6602
# Epoch 45/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.0055 - accuracy: 0.7379
# Epoch 46/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.2332 - accuracy: 0.6311
# Epoch 47/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9057 - accuracy: 0.7573
# Epoch 48/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.9166 - accuracy: 0.7184
# Epoch 49/200
# 21/21 [==============================] - 0s 1ms/step - loss: 1.0696 - accuracy: 0.7087
# Epoch 50/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9566 - accuracy: 0.6990
# Epoch 51/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9575 - accuracy: 0.7184
# Epoch 52/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9068 - accuracy: 0.7379
# Epoch 53/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9616 - accuracy: 0.6990
# Epoch 54/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8507 - accuracy: 0.7573
# Epoch 55/200
# 21/21 [==============================] - 0s 2ms/step - loss: 1.0355 - accuracy: 0.6796
# Epoch 56/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9162 - accuracy: 0.7087
# Epoch 57/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.9212 - accuracy: 0.7282
# Epoch 58/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9589 - accuracy: 0.7379
# Epoch 59/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9208 - accuracy: 0.7476
# Epoch 60/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9341 - accuracy: 0.6893
# Epoch 61/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6960 - accuracy: 0.8155
# Epoch 62/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7691 - accuracy: 0.7379
# Epoch 63/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6490 - accuracy: 0.8058
# Epoch 64/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6965 - accuracy: 0.8058
# Epoch 65/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6063 - accuracy: 0.7864
# Epoch 66/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5926 - accuracy: 0.8058
# Epoch 67/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7800 - accuracy: 0.7767
# Epoch 68/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7140 - accuracy: 0.7573
# Epoch 69/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.8155
# Epoch 70/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7473 - accuracy: 0.7476
# Epoch 71/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7199 - accuracy: 0.7476
# Epoch 72/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7622 - accuracy: 0.7573
# Epoch 73/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7565 - accuracy: 0.7670
# Epoch 74/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5736 - accuracy: 0.8447
# Epoch 75/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6003 - accuracy: 0.8155
# Epoch 76/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6078 - accuracy: 0.8155
# Epoch 77/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.8447
# Epoch 78/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.7961
# Epoch 79/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6436 - accuracy: 0.8058
# Epoch 80/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6032 - accuracy: 0.7864
# Epoch 81/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.8058
# Epoch 82/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4407 - accuracy: 0.8738
# Epoch 83/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6648 - accuracy: 0.8350
# Epoch 84/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5427 - accuracy: 0.8447
# Epoch 85/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.8544
# Epoch 86/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5773 - accuracy: 0.7961
# Epoch 87/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6483 - accuracy: 0.7864
# Epoch 88/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5779 - accuracy: 0.8350
# Epoch 89/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5927 - accuracy: 0.8058
# Epoch 90/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5942 - accuracy: 0.8058
# Epoch 91/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4553 - accuracy: 0.8835
# Epoch 92/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5910 - accuracy: 0.7864
# Epoch 93/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5140 - accuracy: 0.8155
# Epoch 94/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4723 - accuracy: 0.8350
# Epoch 95/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5133 - accuracy: 0.8447
# Epoch 96/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3998 - accuracy: 0.8738
# Epoch 97/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8835
# Epoch 98/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7269 - accuracy: 0.7670
# Epoch 99/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5139 - accuracy: 0.8350
# Epoch 100/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.8252
# Epoch 101/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5441 - accuracy: 0.8350
# Epoch 102/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4544 - accuracy: 0.8544
# Epoch 103/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5216 - accuracy: 0.8350
# Epoch 104/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3958 - accuracy: 0.8835
# Epoch 105/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3789 - accuracy: 0.8738
# Epoch 106/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4546 - accuracy: 0.8544
# Epoch 107/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3354 - accuracy: 0.8738
# Epoch 108/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5090 - accuracy: 0.8447
# Epoch 109/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4437 - accuracy: 0.8738
# Epoch 110/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4409 - accuracy: 0.8544
# Epoch 111/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 0.8544
# Epoch 112/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4650 - accuracy: 0.8544
# Epoch 113/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8932
# Epoch 114/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4648 - accuracy: 0.8447
# Epoch 115/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4473 - accuracy: 0.8252
# Epoch 116/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.8544
# Epoch 117/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.9223
# Epoch 118/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.9029
# Epoch 119/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5327 - accuracy: 0.8641
# Epoch 120/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8932
# Epoch 121/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4257 - accuracy: 0.8544
# Epoch 122/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8544
# Epoch 123/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5270 - accuracy: 0.8447
# Epoch 124/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3121 - accuracy: 0.9029
# Epoch 125/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3196 - accuracy: 0.9029
# Epoch 126/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4886 - accuracy: 0.8447
# Epoch 127/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3924 - accuracy: 0.8641
# Epoch 128/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5615 - accuracy: 0.8350
# Epoch 129/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3797 - accuracy: 0.8544
# Epoch 130/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.9029
# Epoch 131/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.8447
# Epoch 132/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4812 - accuracy: 0.8544
# Epoch 133/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4776 - accuracy: 0.8544
# Epoch 134/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2984 - accuracy: 0.9417
# Epoch 135/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8835
# Epoch 136/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3659 - accuracy: 0.8835
# Epoch 137/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3278 - accuracy: 0.8932
# Epoch 138/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3710 - accuracy: 0.8932
# Epoch 139/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.9320
# Epoch 140/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8932
# Epoch 141/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3100 - accuracy: 0.8932
# Epoch 142/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4004 - accuracy: 0.8544
# Epoch 143/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4288 - accuracy: 0.8350
# Epoch 144/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2972 - accuracy: 0.9223
# Epoch 145/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8447
# Epoch 146/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3967 - accuracy: 0.8738
# Epoch 147/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3726 - accuracy: 0.8641
# Epoch 148/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2888 - accuracy: 0.9029
# Epoch 149/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4894 - accuracy: 0.8447
# Epoch 150/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.9223
# Epoch 151/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4358 - accuracy: 0.8544
# Epoch 152/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3742 - accuracy: 0.8738
# Epoch 153/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2437 - accuracy: 0.9515
# Epoch 154/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8932
# Epoch 155/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5034 - accuracy: 0.8350
# Epoch 156/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3273 - accuracy: 0.8932
# Epoch 157/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3377 - accuracy: 0.9029
# Epoch 158/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2864 - accuracy: 0.8932
# Epoch 159/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3472 - accuracy: 0.8641
# Epoch 160/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2295 - accuracy: 0.9223
# Epoch 161/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3680 - accuracy: 0.8738
# Epoch 162/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8447
# Epoch 163/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2839 - accuracy: 0.9320
# Epoch 164/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3208 - accuracy: 0.9126
# Epoch 165/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.4162 - accuracy: 0.8835
# Epoch 166/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1629 - accuracy: 0.9417
# Epoch 167/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.9126
# Epoch 168/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2287 - accuracy: 0.9126
# Epoch 169/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3265 - accuracy: 0.9223
# Epoch 170/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.9223
# Epoch 171/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.9223
# Epoch 172/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2109 - accuracy: 0.9515
# Epoch 173/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9126
# Epoch 174/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.9126
# Epoch 175/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2689 - accuracy: 0.9126
# Epoch 176/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3466 - accuracy: 0.9029
# Epoch 177/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3218 - accuracy: 0.9029
# Epoch 178/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.9223
# Epoch 179/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3353 - accuracy: 0.8641
# Epoch 180/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2652 - accuracy: 0.9223
# Epoch 181/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.9223
# Epoch 182/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8835
# Epoch 183/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2684 - accuracy: 0.9320
# Epoch 184/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1990 - accuracy: 0.9515
# Epoch 185/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8932
# Epoch 186/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8835
# Epoch 187/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3243 - accuracy: 0.8641
# Epoch 188/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2522 - accuracy: 0.9223
# Epoch 189/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2880 - accuracy: 0.8932
# Epoch 190/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2887 - accuracy: 0.9223
# Epoch 191/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2804 - accuracy: 0.9223
# Epoch 192/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2043 - accuracy: 0.9223
# Epoch 193/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.1859 - accuracy: 0.9612
# Epoch 194/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.9126
# Epoch 195/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2865 - accuracy: 0.8932
# Epoch 196/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2940 - accuracy: 0.9029
# Epoch 197/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2448 - accuracy: 0.9417
# Epoch 198/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2343 - accuracy: 0.9126
# Epoch 199/200
# 21/21 [==============================] - 0s 1ms/step - loss: 0.2719 - accuracy: 0.8932
# Epoch 200/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8835
# model created
# e:\my_projects\convocraft_chatbot\env_chat\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
